# %%
# !pip install tensorflow matplotlib numpy scikit-learn seaborn nltk

# %%
# Implement the Continuous Bag of Words (CBOW) Model for the given (textual
# document 1) using the below steps:
# a. Data preparation
# b. Generate training data
# c. Train model
# d. Output

# %%
# ============================================================
# Continuous Bag of Words (CBOW) Model Implementation
# ============================================================

# a. Import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from sklearn.manifold import TSNE
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Download NLTK data (run once)
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

print(f"TensorFlow version: {tf.__version__}")

# For reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# ============================================================
# a. Data Preparation
# ============================================================

print("=" * 60)
print("STAGE A: DATA PREPARATION")
print("=" * 60)

def load_and_preprocess_text_data():
    """
    Load and preprocess textual data for CBOW model
    """
    # Sample textual document (you can replace this with any text dataset)
    sample_text = """
    Natural language processing is a subfield of linguistics and computer science. 
    It focuses on the interactions between computers and human language. 
    Machine learning models can understand and process natural language. 
    Deep learning has revolutionized natural language processing in recent years. 
    Word embeddings represent words as vectors in continuous space. 
    Continuous Bag of Words is a popular word embedding technique. 
    Neural networks learn contextual relationships between words. 
    Language models predict the probability of word sequences. 
    Text preprocessing is essential for natural language processing tasks. 
    Tokenization splits text into individual words or tokens.
    """
    
    # Alternative: Load from file (uncomment to use your own file)
    # with open('your_text_file.txt', 'r', encoding='utf-8') as file:
    #     sample_text = file.read()
    
    print("📄 SAMPLE TEXT DOCUMENT:")
    print(sample_text[:500] + "..." if len(sample_text) > 500 else sample_text)
    
    return sample_text

def preprocess_text(text):
    """
    Preprocess the text: lowercase, remove punctuation, tokenize
    """
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\d+', '', text)
    
    # Tokenize
    tokens = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and len(token) > 1]
    
    return tokens

# Load and preprocess data
text_data = load_and_preprocess_text_data()
tokens = preprocess_text(text_data)

print(f"\n📊 TEXT STATISTICS:")
print(f"Total tokens: {len(tokens)}")
print(f"Unique tokens: {len(set(tokens))}")
print(f"First 20 tokens: {tokens[:20]}")

# Build vocabulary
word_freq = Counter(tokens)
vocab = sorted(word_freq, key=word_freq.get, reverse=True)
word_to_index = {word: idx for idx, word in enumerate(vocab)}
index_to_word = {idx: word for idx, word in enumerate(vocab)}

vocab_size = len(vocab)
print(f"\n📚 VOCABULARY:")
print(f"Vocabulary size: {vocab_size}")
print(f"Most common words: {word_freq.most_common(10)}")

# ============================================================
# b. Generate Training Data
# ============================================================

print("\n" + "=" * 60)
print("STAGE B: GENERATE TRAINING DATA")
print("=" * 60)

def generate_cbow_data(tokens, word_to_index, window_size=2):
    """
    Generate training data for CBOW model
    """
    X = []  # Context words
    y = []  # Target words
    
    for i in range(window_size, len(tokens) - window_size):
        # Get context words (surrounding words)
        context = []
        for j in range(-window_size, window_size + 1):
            if j != 0:  # Skip the target word itself
                context.append(tokens[i + j])
        
        # Get target word
        target = tokens[i]
        
        # Convert to indices
        context_indices = [word_to_index[word] for word in context]
        target_index = word_to_index[target]
        
        X.append(context_indices)
        y.append(target_index)
    
    return np.array(X), np.array(y)

# Generate training data
window_size = 2
X, y = generate_cbow_data(tokens, word_to_index, window_size)

print(f"📊 TRAINING DATA SHAPE:")
print(f"Context words (X): {X.shape}")
print(f"Target words (y): {y.shape}")
print(f"Window size: {window_size}")
print(f"Context words per sample: {X.shape[1]}")

# Display sample training data
print(f"\n🔍 SAMPLE TRAINING DATA:")
for i in range(5):
    context_words = [index_to_word[idx] for idx in X[i]]
    target_word = index_to_word[y[i]]
    print(f"Context: {context_words} -> Target: {target_word}")

# ============================================================
# c. Train Model
# ============================================================

print("\n" + "=" * 60)
print("STAGE C: TRAIN CBOW MODEL")
print("=" * 60)

def build_cbow_model(vocab_size, embedding_dim=50, window_size=2):
    """
    Build CBOW model architecture
    """
    model = models.Sequential([
        # Embedding layer for context words
        layers.Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=window_size * 2,
                        name='embedding'),
        
        # Average the embeddings of context words
        layers.GlobalAveragePooling1D(name='average_pooling'),
        
        # Dense layer with ReLU activation
        layers.Dense(128, activation='relu', name='hidden_layer'),
        layers.Dropout(0.3),
        
        # Output layer with softmax for word prediction
        layers.Dense(vocab_size, activation='softmax', name='output')
    ])
    
    return model

# Model parameters
embedding_dim = 50
window_size = 2

# Build model
cbow_model = build_cbow_model(vocab_size, embedding_dim, window_size)

print("🔧 CBOW MODEL ARCHITECTURE:")
cbow_model.summary()

# Compile the model
cbow_model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("\n✅ MODEL COMPILED:")
print(f"Optimizer: Adam (lr=0.001)")
print(f"Loss: Sparse Categorical Crossentropy")
print(f"Metrics: Accuracy")

# Train the model
print("\n🚀 TRAINING CBOW MODEL...")
history = cbow_model.fit(
    X, y,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    shuffle=True
)

print("\n✅ Training completed!")

# ============================================================
# d. Output
# ============================================================

print("\n" + "=" * 60)
print("STAGE D: OUTPUT AND EVALUATION")
print("=" * 60)

# Training history visualization
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('CBOW Model Training Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('CBOW Model Training Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Extract word embeddings
embedding_layer = cbow_model.get_layer('embedding')
weights = embedding_layer.get_weights()[0]
print(f"\n📊 WORD EMBEDDINGS:")
print(f"Embedding matrix shape: {weights.shape}")

# Visualize word embeddings using t-SNE
def visualize_embeddings(weights, words, num_words=20):
    """
    Visualize word embeddings using t-SNE
    """
    # Get top N words
    top_words = words[:num_words]
    top_indices = [word_to_index[word] for word in top_words]
    top_embeddings = weights[top_indices]
    
    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=min(5, num_words-1))
    embeddings_2d = tsne.fit_transform(top_embeddings)
    
    # Plot
    plt.figure(figsize=(12, 8))
    plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], alpha=0.7)
    
    for i, word in enumerate(top_words):
        plt.annotate(word, (embeddings_2d[i, 0], embeddings_2d[i, 1]), 
                    fontsize=12, alpha=0.8)
    
    plt.title('Word Embeddings Visualization (t-SNE)', fontsize=16, fontweight='bold')
    plt.xlabel('t-SNE Component 1')
    plt.ylabel('t-SNE Component 2')
    plt.grid(True, alpha=0.3)
    plt.show()

# Visualize top words
top_words = [word for word, _ in word_freq.most_common(20)]
visualize_embeddings(weights, top_words)

# Function to find similar words
def find_similar_words(word, weights, word_to_index, index_to_word, top_n=5):
    """
    Find similar words based on cosine similarity
    """
    if word not in word_to_index:
        return f"Word '{word}' not in vocabulary"
    
    # Get word vector
    word_idx = word_to_index[word]
    word_vec = weights[word_idx]
    
    # Calculate cosine similarities
    similarities = {}
    for idx, vec in enumerate(weights):
        if idx != word_idx:
            cosine_sim = np.dot(word_vec, vec) / (np.linalg.norm(word_vec) * np.linalg.norm(vec))
            similarities[index_to_word[idx]] = cosine_sim
    
    # Get top N similar words
    similar_words = sorted(similarities.items(), key=lambda x: x[1], reverse=True)[:top_n]
    
    return similar_words

# Test similar words
print("\n🔍 SIMILAR WORD ANALYSIS:")
test_words = ['natural', 'language', 'learning', 'processing']
for word in test_words:
    if word in word_to_index:
        similar = find_similar_words(word, weights, word_to_index, index_to_word)
        print(f"Words similar to '{word}': {similar}")

# Word prediction function
def predict_target_word(context_words, model, word_to_index, index_to_word, top_k=3):
    """
    Predict target word given context words
    """
    # Convert context words to indices
    context_indices = [word_to_index[word] for word in context_words if word in word_to_index]
    
    if len(context_indices) != window_size * 2:
        return "Invalid context words"
    
    # Reshape for prediction
    context_array = np.array([context_indices])
    
    # Make prediction
    predictions = model.predict(context_array, verbose=0)[0]
    
    # Get top K predictions
    top_indices = np.argsort(predictions)[-top_k:][::-1]
    top_words = [(index_to_word[idx], predictions[idx]) for idx in top_indices]
    
    return top_words

# Test word prediction
print(f"\n🎯 WORD PREDICTION EXAMPLES:")
test_contexts = [
    ['natural', 'language', 'revolutionized', 'deep'],
    ['word', 'embeddings', 'represent', 'words'],
    ['machine', 'learning', 'models', 'understand']
]

for context in test_contexts:
    predictions = predict_target_word(context, cbow_model, word_to_index, index_to_word)
    print(f"Context: {context} -> Predictions: {predictions}")

# Save word embeddings
def save_embeddings(weights, word_to_index, filename='cbow_embeddings.txt'):
    """
    Save word embeddings to file
    """
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(f"{vocab_size} {embedding_dim}\n")
        for word, idx in word_to_index.items():
            vec = ' '.join(map(str, weights[idx]))
            f.write(f"{word} {vec}\n")
    print(f"✅ Word embeddings saved to {filename}")

save_embeddings(weights, word_to_index)

# Final model evaluation
print(f"\n📈 FINAL MODEL EVALUATION:")
final_loss, final_accuracy = cbow_model.evaluate(X, y, verbose=0)
print(f"Final Training Loss: {final_loss:.4f}")
print(f"Final Training Accuracy: {final_accuracy:.4f}")

# Display vocabulary statistics
print(f"\n📚 VOCABULARY STATISTICS:")
print(f"Total words in vocabulary: {vocab_size}")
print(f"Embedding dimension: {embedding_dim}")
print(f"Window size: {window_size}")
print(f"Training samples: {len(X)}")

# Show some learned relationships
print(f"\n🔗 LEARNED WORD RELATIONSHIPS:")
relationship_examples = [
    (['natural', 'language'], 'processing'),
    (['word', 'embeddings'], 'represent'),
    (['machine', 'learning'], 'models')
]

for context, expected in relationship_examples:
    if all(word in word_to_index for word in context):
        prediction = predict_target_word(context, cbow_model, word_to_index, index_to_word, top_k=1)
        print(f"Context: {context} | Expected: '{expected}' | Predicted: '{prediction[0][0]}'")

print("\n" + "=" * 70)
print("CBOW MODEL IMPLEMENTATION COMPLETE!")
print("=" * 70)
# Out:
# TensorFlow version: 2.20.0
# ============================================================
# STAGE A: DATA PREPARATION
# ============================================================
# 📄 SAMPLE TEXT DOCUMENT:
#
#     Natural language processing is a subfield of linguistics and computer science.
#     It focuses on the interactions between computers and human language.
#     Machine learning models can understand and process natural language.
#     Deep learning has revolutionized natural language processing in recent years.
#     Word embeddings represent words as vectors in continuous space.
#     Continuous Bag of Words is a popular word embedding technique.
#     Neural networks learn contextual relationsh...
#
# 📊 TEXT STATISTICS:
# Total tokens: 66
# Unique tokens: 47
# First 20 tokens: ['natural', 'language', 'processing', 'subfield', 'linguistics', 'computer', 'science', 'focuses', 'interactions', 'computers', 'human', 'language', 'machine', 'learning', 'models', 'understand', 'process', 'natural', 'language', 'deep']
#
# 📚 VOCABULARY:
# Vocabulary size: 47
# Most common words: [('language', 6), ('natural', 4), ('words', 4), ('processing', 3), ('word', 3), ('learning', 2), ('models', 2), ('continuous', 2), ('text', 2), ('subfield', 1)]
#
# ============================================================
# STAGE B: GENERATE TRAINING DATA
# ============================================================
# 📊 TRAINING DATA SHAPE:
# Context words (X): (62, 4)
# Target words (y): (62,)
# Window size: 2
# Context words per sample: 4
#
# 🔍 SAMPLE TRAINING DATA:
# Context: ['natural', 'language', 'subfield', 'linguistics'] -> Target: processing
# Context: ['language', 'processing', 'linguistics', 'computer'] -> Target: subfield
# Context: ['processing', 'subfield', 'computer', 'science'] -> Target: linguistics
# Context: ['subfield', 'linguistics', 'science', 'focuses'] -> Target: computer
# Context: ['linguistics', 'computer', 'focuses', 'interactions'] -> Target: science
#
# ============================================================
# STAGE C: TRAIN CBOW MODEL
# ============================================================
# 🔧 CBOW MODEL ARCHITECTURE:
# C:\Users\Yoda ji\Favorites\timewaste\timewaste\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling                      │ ?                           │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hidden_layer (Dense)                 │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output (Dense)                       │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ✅ MODEL COMPILED:
# Optimizer: Adam (lr=0.001)
# Loss: Sparse Categorical Crossentropy
# Metrics: Accuracy
#
# 🚀 TRAINING CBOW MODEL...
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.0000e+00 - loss: 3.8529 - val_accuracy: 0.0769 - val_loss: 3.8450
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0204 - loss: 3.8469 - val_accuracy: 0.1538 - val_loss: 3.8458
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0816 - loss: 3.8410 - val_accuracy: 0.0769 - val_loss: 3.8462
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1429 - loss: 3.8365 - val_accuracy: 0.0769 - val_loss: 3.8467
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2041 - loss: 3.8324 - val_accuracy: 0.0769 - val_loss: 3.8472
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2245 - loss: 3.8256 - val_accuracy: 0.0769 - val_loss: 3.8476
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1837 - loss: 3.8216 - val_accuracy: 0.0769 - val_loss: 3.8479
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1429 - loss: 3.8185 - val_accuracy: 0.0769 - val_loss: 3.8482
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2245 - loss: 3.8119 - val_accuracy: 0.0769 - val_loss: 3.8483
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1837 - loss: 3.8049 - val_accuracy: 0.0769 - val_loss: 3.8485
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1837 - loss: 3.7990 - val_accuracy: 0.0769 - val_loss: 3.8487
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1837 - loss: 3.7916 - val_accuracy: 0.0769 - val_loss: 3.8490
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1429 - loss: 3.7905 - val_accuracy: 0.0769 - val_loss: 3.8492
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2245 - loss: 3.7797 - val_accuracy: 0.0769 - val_loss: 3.8493
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1837 - loss: 3.7713 - val_accuracy: 0.0769 - val_loss: 3.8494
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2245 - loss: 3.7573 - val_accuracy: 0.0769 - val_loss: 3.8496
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2449 - loss: 3.7472 - val_accuracy: 0.0769 - val_loss: 3.8497
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2041 - loss: 3.7426 - val_accuracy: 0.0769 - val_loss: 3.8499
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1837 - loss: 3.7255 - val_accuracy: 0.0769 - val_loss: 3.8502
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2041 - loss: 3.7150 - val_accuracy: 0.0769 - val_loss: 3.8504
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1837 - loss: 3.6932 - val_accuracy: 0.0769 - val_loss: 3.8506
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6939 - loss: 1.1932 - val_accuracy: 0.2308 - val_loss: 4.8607
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7347 - loss: 1.1890 - val_accuracy: 0.2308 - val_loss: 4.8798
#
# ✅ Training completed!
#
# ============================================================
# STAGE D: OUTPUT AND EVALUATION
# ============================================================
# 📊 WORD EMBEDDINGS:
# Embedding matrix shape: (47, 50)
# 🔍 SIMILAR WORD ANALYSIS:
# Words similar to 'natural': [('recent', np.float32(0.6838275)), ('process', np.float32(0.5364067)), ('learning', np.float32(0.5275068)), ('years', np.float32(0.40515396)), ('predict', np.float32(0.37529582))]
# Words similar to 'language': [('understand', np.float32(0.6546898)), ('deep', np.float32(0.6431406)), ('revolutionized', np.float32(0.5398024)), ('machine', np.float32(0.44407874)), ('processing', np.float32(0.29596788))]
# Words similar to 'learning': [('process', np.float32(0.83529997)), ('predict', np.float32(0.644102)), ('revolutionized', np.float32(0.6285674)), ('natural', np.float32(0.5275068)), ('deep', np.float32(0.509826))]
# Words similar to 'processing': [('computer', np.float32(0.48965424)), ('deep', np.float32(0.48765722)), ('revolutionized', np.float32(0.4427473)), ('recent', np.float32(0.37349093)), ('linguistics', np.float32(0.36977807))]
#
# 🎯 WORD PREDICTION EXAMPLES:
# Context: ['natural', 'language', 'revolutionized', 'deep'] -> Predictions: [('natural', np.float32(0.32621667)), ('learning', np.float32(0.19286911)), ('deep', np.float32(0.17271903))]
# Context: ['word', 'embeddings', 'represent', 'words'] -> Predictions: [('word', np.float32(0.22170402)), ('embeddings', np.float32(0.20010102)), ('popular', np.float32(0.11855816))]
# Context: ['machine', 'learning', 'models', 'understand'] -> Predictions: [('models', np.float32(0.40543205)), ('language', np.float32(0.14342085)), ('learning', np.float32(0.12717059))]
# ✅ Word embeddings saved to cbow_embeddings.txt
#
# 📈 FINAL MODEL EVALUATION:
# Final Training Loss: 1.8985
# Final Training Accuracy: 0.7097
#
# 📚 VOCABULARY STATISTICS:
# Total words in vocabulary: 47
# Embedding dimension: 50
# Window size: 2
# Training samples: 62
#
# 🔗 LEARNED WORD RELATIONSHIPS:
# Context: ['natural', 'language'] | Expected: 'processing' | Predicted: 'I'
# Context: ['word', 'embeddings'] | Expected: 'represent' | Predicted: 'I'
# Context: ['machine', 'learning'] | Expected: 'models' | Predicted: 'I'
#
# ======================================================================
# CBOW MODEL IMPLEMENTATION COMPLETE!
# ======================================================================

# %%
# ============================================================
# Continuous Bag of Words (CBOW) Model Implementation for CBOW.txt Final
# ============================================================

# a. Import required libraries
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from sklearn.manifold import TSNE
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

# Download NLTK data (run once)
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

print(f"TensorFlow version: {tf.__version__}")

# For reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# ============================================================
# a. Data Preparation
# ============================================================

print("=" * 60)
print("STAGE A: DATA PREPARATION")
print("=" * 60)

def load_and_preprocess_text_data():
    """
    Load and preprocess textual data from CBOW.txt file
    """
    try:
        # Load from CBOW.txt file
        with open('CBOW.txt', 'r', encoding='utf-8') as file:
            sample_text = file.read()
        
        print("📄 LOADED TEXT FROM CBOW.txt:")
        print(sample_text[:500] + "..." if len(sample_text) > 500 else sample_text)
        
        return sample_text
    except FileNotFoundError:
        print("❌ CBOW.txt file not found. Using sample text instead.")
        # Fallback sample text
        sample_text = """
        The speed of transmission is an important point of difference between the two viruses. 
        Influenza has a shorter median incubation period and a shorter serial interval than COVID-19 virus. 
        The serial interval for COVID-19 virus is estimated to be 5-6 days, while for influenza virus, the serial interval is 3 days. 
        This means that influenza can spread faster than COVID-19.
        """
        return sample_text

def preprocess_text(text):
    """
    Preprocess the text: lowercase, remove punctuation, tokenize
    """
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\d+', '', text)
    
    # Tokenize
    tokens = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and len(token) > 1]
    
    return tokens

# Load and preprocess data
text_data = load_and_preprocess_text_data()
tokens = preprocess_text(text_data)

print(f"\n📊 TEXT STATISTICS:")
print(f"Total tokens: {len(tokens)}")
print(f"Unique tokens: {len(set(tokens))}")
print(f"First 20 tokens: {tokens[:20]}")

# Build vocabulary
word_freq = Counter(tokens)
vocab = sorted(word_freq, key=word_freq.get, reverse=True)
word_to_index = {word: idx for idx, word in enumerate(vocab)}
index_to_word = {idx: word for idx, word in enumerate(vocab)}

vocab_size = len(vocab)
print(f"\n📚 VOCABULARY:")
print(f"Vocabulary size: {vocab_size}")
print(f"Most common words: {word_freq.most_common(10)}")

# ============================================================
# b. Generate Training Data
# ============================================================

print("\n" + "=" * 60)
print("STAGE B: GENERATE TRAINING DATA")
print("=" * 60)

def generate_cbow_data(tokens, word_to_index, window_size=2):
    """
    Generate training data for CBOW model
    """
    X = []  # Context words
    y = []  # Target words
    
    for i in range(window_size, len(tokens) - window_size):
        # Get context words (surrounding words)
        context = []
        for j in range(-window_size, window_size + 1):
            if j != 0:  # Skip the target word itself
                context.append(tokens[i + j])
        
        # Get target word
        target = tokens[i]
        
        # Convert to indices
        context_indices = [word_to_index[word] for word in context]
        target_index = word_to_index[target]
        
        X.append(context_indices)
        y.append(target_index)
    
    return np.array(X), np.array(y)

# Generate training data
window_size = 2
X, y = generate_cbow_data(tokens, word_to_index, window_size)

print(f"📊 TRAINING DATA SHAPE:")
print(f"Context words (X): {X.shape}")
print(f"Target words (y): {y.shape}")
print(f"Window size: {window_size}")
print(f"Context words per sample: {X.shape[1]}")

# Display sample training data
print(f"\n🔍 SAMPLE TRAINING DATA:")
for i in range(5):
    context_words = [index_to_word[idx] for idx in X[i]]
    target_word = index_to_word[y[i]]
    print(f"Context: {context_words} -> Target: {target_word}")

# ============================================================
# c. Train Model
# ============================================================

print("\n" + "=" * 60)
print("STAGE C: TRAIN CBOW MODEL")
print("=" * 60)

def build_cbow_model(vocab_size, embedding_dim=50, window_size=2):
    """
    Build CBOW model architecture
    """
    model = models.Sequential([
        # Embedding layer for context words
        layers.Embedding(input_dim=vocab_size, 
                        output_dim=embedding_dim, 
                        input_length=window_size * 2,
                        name='embedding'),
        
        # Average the embeddings of context words
        layers.GlobalAveragePooling1D(name='average_pooling'),
        
        # Dense layer with ReLU activation
        layers.Dense(128, activation='relu', name='hidden_layer'),
        layers.Dropout(0.3),
        
        # Output layer with softmax for word prediction
        layers.Dense(vocab_size, activation='softmax', name='output')
    ])
    
    return model

# Model parameters
embedding_dim = 50
window_size = 2

# Build model
cbow_model = build_cbow_model(vocab_size, embedding_dim, window_size)

print("🔧 CBOW MODEL ARCHITECTURE:")
cbow_model.summary()

# Compile the model
cbow_model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("\n✅ MODEL COMPILED:")
print(f"Optimizer: Adam (lr=0.001)")
print(f"Loss: Sparse Categorical Crossentropy")
print(f"Metrics: Accuracy")

# Train the model
print("\n🚀 TRAINING CBOW MODEL...")
history = cbow_model.fit(
    X, y,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    shuffle=True
)

print("\n✅ Training completed!")

# ============================================================
# d. Output
# ============================================================

print("\n" + "=" * 60)
print("STAGE D: OUTPUT AND EVALUATION")
print("=" * 60)

# Training history visualization
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('CBOW Model Training Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('CBOW Model Training Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Extract word embeddings
embedding_layer = cbow_model.get_layer('embedding')
weights = embedding_layer.get_weights()[0]
print(f"\n📊 WORD EMBEDDINGS:")
print(f"Embedding matrix shape: {weights.shape}")

# Visualize word embeddings using t-SNE
def visualize_embeddings(weights, words, num_words=20):
    """
    Visualize word embeddings using t-SNE
    """
    # Get top N words
    top_words = words[:num_words]
    top_indices = [word_to_index[word] for word in top_words]
    top_embeddings = weights[top_indices]
    
    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=min(5, num_words-1))
    embeddings_2d = tsne.fit_transform(top_embeddings)
    
    # Plot
    plt.figure(figsize=(12, 8))
    plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], alpha=0.7, s=100)
    
    for i, word in enumerate(top_words):
        plt.annotate(word, (embeddings_2d[i, 0], embeddings_2d[i, 1]), 
                    fontsize=12, alpha=0.8,
                    bbox=dict(boxstyle="round,pad=0.3", facecolor="lightblue", alpha=0.7))
    
    plt.title('Word Embeddings Visualization (t-SNE) - CBOW.txt', fontsize=16, fontweight='bold')
    plt.xlabel('t-SNE Component 1')
    plt.ylabel('t-SNE Component 2')
    plt.grid(True, alpha=0.3)
    plt.show()

# Visualize top words
top_words = [word for word, _ in word_freq.most_common(20)]
visualize_embeddings(weights, top_words)

# Function to find similar words
def find_similar_words(word, weights, word_to_index, index_to_word, top_n=5):
    """
    Find similar words based on cosine similarity
    """
    if word not in word_to_index:
        return f"Word '{word}' not in vocabulary"
    
    # Get word vector
    word_idx = word_to_index[word]
    word_vec = weights[word_idx]
    
    # Calculate cosine similarities
    similarities = {}
    for idx, vec in enumerate(weights):
        if idx != word_idx:
            cosine_sim = np.dot(word_vec, vec) / (np.linalg.norm(word_vec) * np.linalg.norm(vec))
            similarities[index_to_word[idx]] = cosine_sim
    
    # Get top N similar words
    similar_words = sorted(similarities.items(), key=lambda x: x[1], reverse=True)[:top_n]
    
    return similar_words

# Test similar words
print("\n🔍 SIMILAR WORD ANALYSIS:")
test_words = ['virus', 'influenza', 'transmission', 'covid']
for word in test_words:
    if word in word_to_index:
        similar = find_similar_words(word, weights, word_to_index, index_to_word)
        print(f"Words similar to '{word}': {similar}")

# Word prediction function
def predict_target_word(context_words, model, word_to_index, index_to_word, top_k=3):
    """
    Predict target word given context words
    """
    # Convert context words to indices
    context_indices = [word_to_index[word] for word in context_words if word in word_to_index]
    
    if len(context_indices) != window_size * 2:
        return "Invalid context words"
    
    # Reshape for prediction
    context_array = np.array([context_indices])
    
    # Make prediction
    predictions = model.predict(context_array, verbose=0)[0]
    
    # Get top K predictions
    top_indices = np.argsort(predictions)[-top_k:][::-1]
    top_words = [(index_to_word[idx], predictions[idx]) for idx in top_indices]
    
    return top_words

# Test word prediction
print(f"\n🎯 WORD PREDICTION EXAMPLES:")
test_contexts = [
    ['influenza', 'virus', 'serial', 'interval'],
    ['covid', 'virus', 'transmission', 'speed'],
    ['incubation', 'period', 'shorter', 'median']
]

for context in test_contexts:
    predictions = predict_target_word(context, cbow_model, word_to_index, index_to_word)
    print(f"Context: {context} -> Predictions: {predictions}")

# Save word embeddings
def save_embeddings(weights, word_to_index, filename='cbow_embeddings.txt'):
    """
    Save word embeddings to file
    """
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(f"{vocab_size} {embedding_dim}\n")
        for word, idx in word_to_index.items():
            vec = ' '.join(map(str, weights[idx]))
            f.write(f"{word} {vec}\n")
    print(f"✅ Word embeddings saved to {filename}")

save_embeddings(weights, word_to_index)

# Final model evaluation
print(f"\n📈 FINAL MODEL EVALUATION:")
final_loss, final_accuracy = cbow_model.evaluate(X, y, verbose=0)
print(f"Final Training Loss: {final_loss:.4f}")
print(f"Final Training Accuracy: {final_accuracy:.4f}")

# Display vocabulary statistics
print(f"\n📚 VOCABULARY STATISTICS:")
print(f"Total words in vocabulary: {vocab_size}")
print(f"Embedding dimension: {embedding_dim}")
print(f"Window size: {window_size}")
print(f"Training samples: {len(X)}")

# Show some learned relationships
print(f"\n🔗 LEARNED WORD RELATIONSHIPS:")
relationship_examples = [
    (['influenza', 'virus'], 'serial'),
    (['covid', 'virus'], 'transmission'),
    (['incubation', 'period'], 'shorter')
]

for context, expected in relationship_examples:
    if all(word in word_to_index for word in context):
        prediction = predict_target_word(context, cbow_model, word_to_index, index_to_word, top_k=1)
        if prediction and isinstance(prediction, list):
            print(f"Context: {context} | Expected: '{expected}' | Predicted: '{prediction[0][0]}'")

# Additional analysis: Show word frequencies
print(f"\n📊 WORD FREQUENCY ANALYSIS:")
print("Most frequent words in CBOW.txt:")
for word, freq in word_freq.most_common(15):
    print(f"  {word}: {freq} occurrences")

# Semantic relationships analysis
print(f"\n🔍 SEMANTIC RELATIONSHIP ANALYSIS:")
medical_terms = ['virus', 'transmission', 'influenza', 'covid', 'symptoms']
for term in medical_terms:
    if term in word_to_index:
        similar = find_similar_words(term, weights, word_to_index, index_to_word, top_n=3)
        print(f"'{term}' relates to: {similar}")

print("\n" + "=" * 70)
print("CBOW MODEL IMPLEMENTATION FOR CBOW.txt COMPLETE!")
print("=" * 70)
# Out:
# TensorFlow version: 2.20.0
# ============================================================
# STAGE A: DATA PREPARATION
# ============================================================
# 📄 LOADED TEXT FROM CBOW.txt:
# The speed of transmission is an important point of difference between the two viruses. Influenza has a shorter median incubation period (the time from infection to appearance of symptoms) and a shorter serial interval (the time between successive cases) than COVID-19 virus. The serial interval for COVID-19 virus is estimated to be 5-6 days, while for influenza virus, the serial interval is 3 days. This means that influenza can spread faster than COVID-19.
#
# Further, transmission in the first 3-5...
#
# 📊 TEXT STATISTICS:
# Total tokens: 97
# Unique tokens: 62
# First 20 tokens: ['speed', 'transmission', 'important', 'point', 'difference', 'two', 'viruses', 'influenza', 'shorter', 'median', 'incubation', 'period', 'time', 'infection', 'appearance', 'symptoms', 'shorter', 'serial', 'interval', 'time']
#
# 📚 VOCABULARY:
# Vocabulary size: 62
# Most common words: [('transmission', 6), ('influenza', 6), ('covid', 6), ('virus', 6), ('time', 3), ('serial', 3), ('interval', 3), ('days', 3), ('viruses', 2), ('shorter', 2)]
#
# ============================================================
# STAGE B: GENERATE TRAINING DATA
# ============================================================
# 📊 TRAINING DATA SHAPE:
# Context words (X): (93, 4)
# Target words (y): (93,)
# Window size: 2
# Context words per sample: 4
#
# 🔍 SAMPLE TRAINING DATA:
# Context: ['speed', 'transmission', 'point', 'difference'] -> Target: important
# Context: ['transmission', 'important', 'difference', 'two'] -> Target: point
# Context: ['important', 'point', 'two', 'viruses'] -> Target: difference
# Context: ['point', 'difference', 'viruses', 'influenza'] -> Target: two
# Context: ['difference', 'two', 'influenza', 'shorter'] -> Target: viruses
#
# ============================================================
# STAGE C: TRAIN CBOW MODEL
# ============================================================
# 🔧 CBOW MODEL ARCHITECTURE:
# C:\Users\Yoda ji\Favorites\timewaste\timewaste\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling                      │ ?                           │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hidden_layer (Dense)                 │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output (Dense)                       │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ✅ MODEL COMPILED:
# Optimizer: Adam (lr=0.001)
# Loss: Sparse Categorical Crossentropy
# Metrics: Accuracy
#
# 🚀 TRAINING CBOW MODEL...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.0135 - loss: 4.1258 - val_accuracy: 0.0000e+00 - val_loss: 4.1280
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.0946 - loss: 4.1168 - val_accuracy: 0.0000e+00 - val_loss: 4.1282
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1216 - loss: 4.1114 - val_accuracy: 0.0000e+00 - val_loss: 4.1283
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1486 - loss: 4.1049 - val_accuracy: 0.0526 - val_loss: 4.1283
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.1892 - loss: 4.0973 - val_accuracy: 0.0526 - val_loss: 4.1286
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2027 - loss: 4.0892 - val_accuracy: 0.0000e+00 - val_loss: 4.1290
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2162 - loss: 4.0807 - val_accuracy: 0.0000e+00 - val_loss: 4.1293
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2027 - loss: 4.0697 - val_accuracy: 0.0000e+00 - val_loss: 4.1298
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2432 - loss: 4.0612 - val_accuracy: 0.0000e+00 - val_loss: 4.1302
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2162 - loss: 4.0462 - val_accuracy: 0.0000e+00 - val_loss: 4.1306
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2162 - loss: 4.0356 - val_accuracy: 0.0000e+00 - val_loss: 4.1311
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1892 - loss: 4.0138 - val_accuracy: 0.0000e+00 - val_loss: 4.1319
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1486 - loss: 4.0053 - val_accuracy: 0.0000e+00 - val_loss: 4.1330
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1892 - loss: 3.9785 - val_accuracy: 0.0000e+00 - val_loss: 4.1344
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.1892 - loss: 3.9610 - val_accuracy: 0.0000e+00 - val_loss: 4.1362
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1892 - loss: 3.9395 - val_accuracy: 0.0000e+00 - val_loss: 4.1384
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1892 - loss: 3.9107 - val_accuracy: 0.0000e+00 - val_loss: 4.1410
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1622 - loss: 3.8803 - val_accuracy: 0.0000e+00 - val_loss: 4.1442
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1757 - loss: 3.8499 - val_accuracy: 0.0000e+00 - val_loss: 4.1483
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2027 - loss: 3.8022 - val_accuracy: 0.0000e+00 - val_loss: 4.1533
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1622 - loss: 3.7659 - val_accuracy: 0.0000e+00 - val_loss: 4.1596
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1486 - loss: 3.7310 - val_accuracy: 0.0000e+00 - val_loss: 4.1671
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1892 - loss: 3.6825 - val_accuracy: 0.0000e+00 - val_loss: 4.1761
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.2027 - loss: 3.6293 - val_accuracy: 0.0000e+00 - val_loss: 4.1870
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2432 - loss: 3.5796 - val_accuracy: 0.0000e+00 - val_loss: 4.1998
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7703 - loss: 0.9782 - val_accuracy: 0.0526 - val_loss: 6.1586
# ✅ Training completed!
#
# ============================================================
# STAGE D: OUTPUT AND EVALUATION
# ============================================================
# 📊 WORD EMBEDDINGS:
# Embedding matrix shape: (62, 50)
# 🔍 SIMILAR WORD ANALYSIS:
# Words similar to 'virus': [('faster', np.float32(0.6626188)), ('serial', np.float32(0.6482231)), ('hours', np.float32(0.6075903)), ('first', np.float32(0.5844267)), ('estimated', np.float32(0.4886597))]
# Words similar to 'influenza': [('difference', np.float32(0.61355186)), ('point', np.float32(0.4696171)), ('viruses', np.float32(0.4303777)), ('reproductive', np.float32(0.38081577)), ('appear', np.float32(0.3635337))]
# Words similar to 'transmission': [('major', np.float32(0.4490368)), ('symptomatic', np.float32(0.4406994)), ('pre', np.float32(0.40137473)), ('reproductive', np.float32(0.38119364)), ('symptoms', np.float32(0.34167233))]
# Words similar to 'covid': [('prior', np.float32(0.5969879)), ('one', np.float32(0.5709812)), ('symptom', np.float32(0.4371194)), ('time', np.float32(0.3981316)), ('interval', np.float32(0.3101387))]
#
# 🎯 WORD PREDICTION EXAMPLES:
# Context: ['influenza', 'virus', 'serial', 'interval'] -> Predictions: [('serial', np.float32(0.30363697)), ('days', np.float32(0.2143164)), ('interval', np.float32(0.15240811))]
# Context: ['covid', 'virus', 'transmission', 'speed'] -> Predictions: [('transmission', np.float32(0.15011424)), ('virus', np.float32(0.0905484)), ('faster', np.float32(0.08031847))]
# Context: ['incubation', 'period', 'shorter', 'median'] -> Predictions: [('shorter', np.float32(0.25283366)), ('time', np.float32(0.17777435)), ('median', np.float32(0.167969))]
# ✅ Word embeddings saved to cbow_embeddings.txt
#
# 📈 FINAL MODEL EVALUATION:
# Final Training Loss: 1.9244
# Final Training Accuracy: 0.7312
#
# 📚 VOCABULARY STATISTICS:
# Total words in vocabulary: 62
# Embedding dimension: 50
# Window size: 2
# Training samples: 93
#
# 🔗 LEARNED WORD RELATIONSHIPS:
#
# 📊 WORD FREQUENCY ANALYSIS:
# Most frequent words in CBOW.txt:
#   transmission: 6 occurrences
#   influenza: 6 occurrences
#   covid: 6 occurrences
#   virus: 6 occurrences
#   time: 3 occurrences
#   serial: 3 occurrences
#   interval: 3 occurrences
#   days: 3 occurrences
#   viruses: 2 occurrences
#   shorter: 2 occurrences
#   appearance: 2 occurrences
#   symptoms: 2 occurrences
#   major: 2 occurrences
#   driver: 2 occurrences
#   number: 2 occurrences
#
# 🔍 SEMANTIC RELATIONSHIP ANALYSIS:
# 'virus' relates to: [('faster', np.float32(0.6626188)), ('serial', np.float32(0.6482231)), ('hours', np.float32(0.6075903))]
# 'transmission' relates to: [('major', np.float32(0.4490368)), ('symptomatic', np.float32(0.4406994)), ('pre', np.float32(0.40137473))]
# 'influenza' relates to: [('difference', np.float32(0.61355186)), ('point', np.float32(0.4696171)), ('viruses', np.float32(0.4303777))]
# 'covid' relates to: [('prior', np.float32(0.5969879)), ('one', np.float32(0.5709812)), ('symptom', np.float32(0.4371194))]
# 'symptoms' relates to: [('interval', np.float32(0.6040188)), ('appearance', np.float32(0.5888399)), ('appear', np.float32(0.51237714))]
#
# ======================================================================
# CBOW MODEL IMPLEMENTATION FOR CBOW.txt COMPLETE!
# ======================================================================
