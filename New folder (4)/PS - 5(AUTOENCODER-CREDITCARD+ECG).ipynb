# %%
# !pip install tensorflow matplotlib numpy scikit-learn seaborn

# %%
# Implement anomaly detection for given credit card dataset using Autoencoder and
# build the model by using the following steps:
# a. Import required libraries
# b. Upload / access the dataset
# c. Encoder converts it into latent representation
# d. Decoder networks convert it back to the original input
# e. Compile the models with Optimizer, Loss, and Evaluation Metrics

# %%
# a. Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# b. Upload / access the dataset
# Load the dataset
df = pd.read_csv('creditcard.csv')

# Explore the dataset
print("Dataset shape:", df.shape)
print("\nDataset info:")
print(df.info())
print("\nClass distribution:")
print(df['Class'].value_counts())
print("\nPercentage of fraud cases: {:.4f}%".format(df['Class'].value_counts()[1] / len(df) * 100))

# Data preprocessing
# Separate features and target
features = df.drop(['Class', 'Time'], axis=1)  # Remove 'Time' as it's not useful for anomaly detection
labels = df['Class']

# Split the data into normal and fraudulent transactions
normal_data = features[labels == 0]
fraud_data = features[labels == 1]

print(f"Normal transactions: {len(normal_data)}")
print(f"Fraudulent transactions: {len(fraud_data)}")

# Scale the features
scaler = StandardScaler()
normal_data_scaled = scaler.fit_transform(normal_data)
fraud_data_scaled = scaler.transform(fraud_data)

# Split normal data into train and test
X_train, X_test_normal = train_test_split(normal_data_scaled, test_size=0.2, random_state=42)

# Use all fraud data for testing
X_test_fraud = fraud_data_scaled

# Combine test data
X_test = np.concatenate([X_test_normal, X_test_fraud])
y_test = np.concatenate([np.zeros(len(X_test_normal)), np.ones(len(X_test_fraud))])

print(f"Training data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")

# Autoencoder architecture
input_dim = X_train.shape[1]
encoding_dim = 14  # Size of our encoded representations

# c. Encoder converts it into latent representation
# Input layer
input_layer = Input(shape=(input_dim,))

# Encoder
encoder = Dense(encoding_dim * 2, activation='relu')(input_layer)
encoder = Dropout(0.1)(encoder)
encoder = Dense(encoding_dim, activation='relu')(encoder)

# Latent representation
latent_representation = Dense(encoding_dim // 2, activation='relu', name='bottleneck')(encoder)

# d. Decoder networks convert it back to the original input
# Decoder
decoder = Dense(encoding_dim, activation='relu')(latent_representation)
decoder = Dropout(0.1)(decoder)
decoder = Dense(encoding_dim * 2, activation='relu')(decoder)
output_layer = Dense(input_dim, activation='linear')(decoder)

# Create autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer, name='autoencoder')

# Create encoder model
encoder_model = Model(inputs=input_layer, outputs=latent_representation, name='encoder')

# Compile the models
# e. Compile the models with Optimizer, Loss, and Evaluation Metrics
autoencoder.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',  # Mean Squared Error for reconstruction
    metrics=['mae']  # Mean Absolute Error as additional metric
)

print("Autoencoder architecture:")
autoencoder.summary()

# Train the autoencoder
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=0.0001,
    verbose=1
)

# Train on normal transactions only
history = autoencoder.fit(
    X_train, X_train,
    epochs=100,
    batch_size=256,
    validation_split=0.1,
    callbacks=[early_stopping, reduce_lr],
    verbose=1,
    shuffle=True
)

# Evaluate the model
train_predictions = autoencoder.predict(X_train)
test_predictions = autoencoder.predict(X_test)

# Calculate reconstruction error
train_mse = np.mean(np.power(X_train - train_predictions, 2), axis=1)
test_mse = np.mean(np.power(X_test - test_predictions, 2), axis=1)

# Plot training history
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend()

plt.tight_layout()
plt.show()

# Analyze reconstruction errors
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.hist(train_mse, bins=50, alpha=0.7, label='Normal (Train)', color='blue')
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Reconstruction Error - Training Data')
plt.legend()

plt.subplot(1, 2, 2)
normal_test_mse = test_mse[y_test == 0]
fraud_test_mse = test_mse[y_test == 1]

plt.hist(normal_test_mse, bins=50, alpha=0.7, label='Normal (Test)', color='green')
plt.hist(fraud_test_mse, bins=50, alpha=0.7, label='Fraud (Test)', color='red')
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.title('Reconstruction Error - Test Data')
plt.legend()

plt.tight_layout()
plt.show()

# Find optimal threshold using training data
threshold = np.percentile(train_mse, 95)  # 95th percentile of training errors
print(f"Optimal threshold (95th percentile): {threshold:.4f}")

# Make predictions based on threshold
y_pred = (test_mse > threshold).astype(int)

# Evaluation metrics
print("\n" + "="*50)
print("ANOMALY DETECTION RESULTS")
print("="*50)

print(f"Threshold: {threshold:.4f}")
print(f"Fraud detection rate: {np.mean(y_pred[y_test == 1]) * 100:.2f}%")
print(f"False positive rate: {np.mean(y_pred[y_test == 0]) * 100:.2f}%")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Normal', 'Fraud']))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Fraud'], 
            yticklabels=['Normal', 'Fraud'])
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, test_mse)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

print(f"ROC AUC Score: {roc_auc:.4f}")

# Analyze some examples
print("\n" + "="*50)
print("EXAMPLE ANALYSIS")
print("="*50)

# Get some examples
normal_examples = X_test[y_test == 0][:3]
fraud_examples = X_test[y_test == 1][:3]

normal_reconstructions = autoencoder.predict(normal_examples)
fraud_reconstructions = autoencoder.predict(fraud_examples)

normal_errors = np.mean(np.power(normal_examples - normal_reconstructions, 2), axis=1)
fraud_errors = np.mean(np.power(fraud_examples - fraud_reconstructions, 2), axis=1)

print("Normal transactions reconstruction errors:", normal_errors)
print("Fraud transactions reconstruction errors:", fraud_errors)
print("Threshold:", threshold)

# Feature importance analysis (which features contribute most to reconstruction error)
feature_errors = np.mean(np.abs(X_test - test_predictions), axis=0)
feature_importance = pd.DataFrame({
    'Feature': features.columns,
    'Reconstruction_Error': feature_errors
}).sort_values('Reconstruction_Error', ascending=False)

print("\nTop 10 features contributing to reconstruction error:")
print(feature_importance.head(10))
# Out:
# Dataset shape: (284807, 31)
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB
# None
#
# Class distribution:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
#
# Percentage of fraud cases: 0.1727%
# Normal transactions: 284315
# Fraudulent transactions: 492
# Training data shape: (227452, 29)
# Test data shape: (57355, 29)
# Autoencoder architecture:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 29)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 28)                  │             840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 28)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 14)                  │             406 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bottleneck (Dense)                   │ (None, 7)                   │             105 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 14)                  │             112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 14)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 28)                  │             420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 29)                  │             841 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,724 (10.64 KB)
#  Trainable params: 2,724 (10.64 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.8179 - mae: 0.6071 - val_loss: 0.6728 - val_mae: 0.5448 - learning_rate: 0.0010
# Epoch 2/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.6477 - mae: 0.5443 - val_loss: 0.5497 - val_mae: 0.5004 - learning_rate: 0.0010
# Epoch 3/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5804 - mae: 0.5181 - val_loss: 0.4875 - val_mae: 0.4736 - learning_rate: 0.0010
# Epoch 4/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.5509 - mae: 0.5051 - val_loss: 0.4632 - val_mae: 0.4622 - learning_rate: 0.0010
# Epoch 5/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5320 - mae: 0.4976 - val_loss: 0.4492 - val_mae: 0.4563 - learning_rate: 0.0010
# Epoch 6/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5209 - mae: 0.4928 - val_loss: 0.4385 - val_mae: 0.4503 - learning_rate: 0.0010
# Epoch 7/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5109 - mae: 0.4879 - val_loss: 0.4235 - val_mae: 0.4432 - learning_rate: 0.0010
# Epoch 8/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.5059 - mae: 0.4850 - val_loss: 0.4136 - val_mae: 0.4396 - learning_rate: 0.0010
# Epoch 9/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4964 - mae: 0.4813 - val_loss: 0.4186 - val_mae: 0.4441 - learning_rate: 0.0010
# Epoch 10/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4909 - mae: 0.4783 - val_loss: 0.4000 - val_mae: 0.4329 - learning_rate: 0.0010
# Epoch 11/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4872 - mae: 0.4764 - val_loss: 0.3984 - val_mae: 0.4328 - learning_rate: 0.0010
# Epoch 12/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4803 - mae: 0.4743 - val_loss: 0.3902 - val_mae: 0.4296 - learning_rate: 0.0010
# Epoch 13/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4771 - mae: 0.4731 - val_loss: 0.3869 - val_mae: 0.4283 - learning_rate: 0.0010
# Epoch 14/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4756 - mae: 0.4719 - val_loss: 0.3811 - val_mae: 0.4263 - learning_rate: 0.0010
# Epoch 15/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4676 - mae: 0.4699 - val_loss: 0.3790 - val_mae: 0.4256 - learning_rate: 0.0010
# Epoch 16/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4694 - mae: 0.4688 - val_loss: 0.3766 - val_mae: 0.4247 - learning_rate: 0.0010
# Epoch 17/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4639 - mae: 0.4671 - val_loss: 0.3720 - val_mae: 0.4214 - learning_rate: 0.0010
# Epoch 18/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4644 - mae: 0.4657 - val_loss: 0.3715 - val_mae: 0.4210 - learning_rate: 0.0010
# Epoch 19/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4592 - mae: 0.4643 - val_loss: 0.3706 - val_mae: 0.4207 - learning_rate: 0.0010
# Epoch 20/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4570 - mae: 0.4632 - val_loss: 0.3648 - val_mae: 0.4175 - learning_rate: 0.0010
# Epoch 21/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4542 - mae: 0.4616 - val_loss: 0.3619 - val_mae: 0.4156 - learning_rate: 0.0010
# Epoch 22/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4546 - mae: 0.4604 - val_loss: 0.3648 - val_mae: 0.4174 - learning_rate: 0.0010
# Epoch 23/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4516 - mae: 0.4596 - val_loss: 0.3595 - val_mae: 0.4135 - learning_rate: 0.0010
# Epoch 24/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4464 - mae: 0.4578 - val_loss: 0.3571 - val_mae: 0.4121 - learning_rate: 0.0010
# Epoch 25/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4449 - mae: 0.4562 - val_loss: 0.3546 - val_mae: 0.4100 - learning_rate: 0.0010
# Epoch 26/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4466 - mae: 0.4556 - val_loss: 0.3547 - val_mae: 0.4105 - learning_rate: 0.0010
# Epoch 27/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4439 - mae: 0.4544 - val_loss: 0.3533 - val_mae: 0.4087 - learning_rate: 0.0010
# Epoch 28/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4412 - mae: 0.4526 - val_loss: 0.3492 - val_mae: 0.4065 - learning_rate: 0.0010
# Epoch 29/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4382 - mae: 0.4511 - val_loss: 0.3493 - val_mae: 0.4056 - learning_rate: 0.0010
# Epoch 30/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4368 - mae: 0.4498 - val_loss: 0.3448 - val_mae: 0.4035 - learning_rate: 0.0010
# Epoch 31/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4352 - mae: 0.4485 - val_loss: 0.3413 - val_mae: 0.4016 - learning_rate: 0.0010
# Epoch 32/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4342 - mae: 0.4470 - val_loss: 0.3383 - val_mae: 0.3989 - learning_rate: 0.0010
# Epoch 33/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4284 - mae: 0.4447 - val_loss: 0.3366 - val_mae: 0.3986 - learning_rate: 0.0010
# Epoch 34/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4276 - mae: 0.4439 - val_loss: 0.3369 - val_mae: 0.3984 - learning_rate: 0.0010
# Epoch 35/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4289 - mae: 0.4432 - val_loss: 0.3364 - val_mae: 0.3964 - learning_rate: 0.0010
# Epoch 36/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4239 - mae: 0.4418 - val_loss: 0.3351 - val_mae: 0.3962 - learning_rate: 0.0010
# Epoch 37/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4238 - mae: 0.4408 - val_loss: 0.3291 - val_mae: 0.3935 - learning_rate: 0.0010
# Epoch 38/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4206 - mae: 0.4397 - val_loss: 0.3278 - val_mae: 0.3923 - learning_rate: 0.0010
# Epoch 39/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4191 - mae: 0.4386 - val_loss: 0.3265 - val_mae: 0.3919 - learning_rate: 0.0010
# Epoch 40/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4185 - mae: 0.4376 - val_loss: 0.3243 - val_mae: 0.3894 - learning_rate: 0.0010
# Epoch 41/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4169 - mae: 0.4365 - val_loss: 0.3240 - val_mae: 0.3892 - learning_rate: 0.0010
# Epoch 42/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4200 - mae: 0.4367 - val_loss: 0.3265 - val_mae: 0.3903 - learning_rate: 0.0010
# Epoch 43/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4159 - mae: 0.4355 - val_loss: 0.3247 - val_mae: 0.3902 - learning_rate: 0.0010
# Epoch 44/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4137 - mae: 0.4346 - val_loss: 0.3191 - val_mae: 0.3866 - learning_rate: 0.0010
# Epoch 45/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4121 - mae: 0.4337 - val_loss: 0.3220 - val_mae: 0.3877 - learning_rate: 0.0010
# Epoch 46/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4163 - mae: 0.4339 - val_loss: 0.3186 - val_mae: 0.3860 - learning_rate: 0.0010
# Epoch 47/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4121 - mae: 0.4325 - val_loss: 0.3199 - val_mae: 0.3866 - learning_rate: 0.0010
# Epoch 48/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4081 - mae: 0.4316 - val_loss: 0.3192 - val_mae: 0.3870 - learning_rate: 0.0010
# Epoch 49/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4049 - mae: 0.4304 - val_loss: 0.3186 - val_mae: 0.3848 - learning_rate: 0.0010
# Epoch 50/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4077 - mae: 0.4302 - val_loss: 0.3160 - val_mae: 0.3825 - learning_rate: 0.0010
# Epoch 51/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4094 - mae: 0.4300 - val_loss: 0.3146 - val_mae: 0.3820 - learning_rate: 0.0010
# Epoch 52/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4047 - mae: 0.4284 - val_loss: 0.3139 - val_mae: 0.3805 - learning_rate: 0.0010
# Epoch 53/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4053 - mae: 0.4278 - val_loss: 0.3142 - val_mae: 0.3808 - learning_rate: 0.0010
# Epoch 54/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4060 - mae: 0.4274 - val_loss: 0.3166 - val_mae: 0.3832 - learning_rate: 0.0010
# Epoch 55/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4050 - mae: 0.4269 - val_loss: 0.3149 - val_mae: 0.3831 - learning_rate: 0.0010
# Epoch 56/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4019 - mae: 0.4258 - val_loss: 0.3125 - val_mae: 0.3787 - learning_rate: 0.0010
# Epoch 57/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4027 - mae: 0.4254 - val_loss: 0.3110 - val_mae: 0.3802 - learning_rate: 0.0010
# Epoch 58/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4028 - mae: 0.4247 - val_loss: 0.3114 - val_mae: 0.3791 - learning_rate: 0.0010
# Epoch 59/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4029 - mae: 0.4244 - val_loss: 0.3412 - val_mae: 0.3991 - learning_rate: 0.0010
# Epoch 60/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4012 - mae: 0.4249 - val_loss: 0.3059 - val_mae: 0.3755 - learning_rate: 0.0010
# Epoch 61/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3972 - mae: 0.4222 - val_loss: 0.3069 - val_mae: 0.3763 - learning_rate: 0.0010
# Epoch 62/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3987 - mae: 0.4217 - val_loss: 0.3173 - val_mae: 0.3828 - learning_rate: 0.0010
# Epoch 63/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3981 - mae: 0.4217 - val_loss: 0.3085 - val_mae: 0.3765 - learning_rate: 0.0010
# Epoch 64/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3975 - mae: 0.4211 - val_loss: 0.3047 - val_mae: 0.3752 - learning_rate: 0.0010
# Epoch 65/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3981 - mae: 0.4207 - val_loss: 0.3073 - val_mae: 0.3762 - learning_rate: 0.0010
# Epoch 66/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3969 - mae: 0.4200 - val_loss: 0.3059 - val_mae: 0.3751 - learning_rate: 0.0010
# Epoch 67/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3971 - mae: 0.4212 - val_loss: 0.3080 - val_mae: 0.3761 - learning_rate: 0.0010
# Epoch 68/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3954 - mae: 0.4187 - val_loss: 0.3030 - val_mae: 0.3735 - learning_rate: 0.0010
# Epoch 69/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3911 - mae: 0.4181 - val_loss: 0.3044 - val_mae: 0.3740 - learning_rate: 0.0010
# Epoch 70/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3908 - mae: 0.4178 - val_loss: 0.3079 - val_mae: 0.3755 - learning_rate: 0.0010
# Epoch 71/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3932 - mae: 0.4177 - val_loss: 0.3000 - val_mae: 0.3717 - learning_rate: 0.0010
# Epoch 72/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3908 - mae: 0.4170 - val_loss: 0.3052 - val_mae: 0.3755 - learning_rate: 0.0010
# Epoch 73/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3921 - mae: 0.4178 - val_loss: 0.3036 - val_mae: 0.3739 - learning_rate: 0.0010
# Epoch 74/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3909 - mae: 0.4166 - val_loss: 0.3019 - val_mae: 0.3717 - learning_rate: 0.0010
# Epoch 75/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3902 - mae: 0.4156 - val_loss: 0.3005 - val_mae: 0.3701 - learning_rate: 0.0010
# Epoch 76/100
# 793/800 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4011 - mae: 0.4189
# Epoch 76: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3935 - mae: 0.4167 - val_loss: 0.3135 - val_mae: 0.3797 - learning_rate: 0.0010
# Epoch 77/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3853 - mae: 0.4136 - val_loss: 0.2975 - val_mae: 0.3685 - learning_rate: 5.0000e-04
# Epoch 78/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3864 - mae: 0.4135 - val_loss: 0.2978 - val_mae: 0.3691 - learning_rate: 5.0000e-04
# Epoch 79/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3840 - mae: 0.4125 - val_loss: 0.2972 - val_mae: 0.3692 - learning_rate: 5.0000e-04
# Epoch 80/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3861 - mae: 0.4124 - val_loss: 0.2967 - val_mae: 0.3679 - learning_rate: 5.0000e-04
# Epoch 81/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3854 - mae: 0.4125 - val_loss: 0.2980 - val_mae: 0.3693 - learning_rate: 5.0000e-04
# Epoch 82/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3846 - mae: 0.4120 - val_loss: 0.2967 - val_mae: 0.3681 - learning_rate: 5.0000e-04
# Epoch 83/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3856 - mae: 0.4120 - val_loss: 0.2958 - val_mae: 0.3675 - learning_rate: 5.0000e-04
# Epoch 84/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3853 - mae: 0.4121 - val_loss: 0.2957 - val_mae: 0.3678 - learning_rate: 5.0000e-04
# Epoch 85/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3804 - mae: 0.4111 - val_loss: 0.2958 - val_mae: 0.3673 - learning_rate: 5.0000e-04
# Epoch 86/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3856 - mae: 0.4116 - val_loss: 0.2961 - val_mae: 0.3677 - learning_rate: 5.0000e-04
# Epoch 87/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3818 - mae: 0.4114 - val_loss: 0.2941 - val_mae: 0.3669 - learning_rate: 5.0000e-04
# Epoch 88/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3845 - mae: 0.4110 - val_loss: 0.2944 - val_mae: 0.3672 - learning_rate: 5.0000e-04
# Epoch 89/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3856 - mae: 0.4106 - val_loss: 0.2940 - val_mae: 0.3657 - learning_rate: 5.0000e-04
# Epoch 90/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3837 - mae: 0.4107 - val_loss: 0.2956 - val_mae: 0.3680 - learning_rate: 5.0000e-04
# Epoch 91/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3803 - mae: 0.4106 - val_loss: 0.2943 - val_mae: 0.3669 - learning_rate: 5.0000e-04
# Epoch 92/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3839 - mae: 0.4106 - val_loss: 0.2959 - val_mae: 0.3680 - learning_rate: 5.0000e-04
# Epoch 93/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3824 - mae: 0.4102 - val_loss: 0.2957 - val_mae: 0.3676 - learning_rate: 5.0000e-04
# Epoch 94/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3813 - mae: 0.4099 - val_loss: 0.2935 - val_mae: 0.3666 - learning_rate: 5.0000e-04
# Epoch 95/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3812 - mae: 0.4098 - val_loss: 0.2924 - val_mae: 0.3655 - learning_rate: 5.0000e-04
# Epoch 96/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3803 - mae: 0.4093 - val_loss: 0.2937 - val_mae: 0.3661 - learning_rate: 5.0000e-04
# Epoch 97/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3826 - mae: 0.4098 - val_loss: 0.2941 - val_mae: 0.3665 - learning_rate: 5.0000e-04
# Epoch 98/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3800 - mae: 0.4097 - val_loss: 0.2952 - val_mae: 0.3672 - learning_rate: 5.0000e-04
# Epoch 99/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3812 - mae: 0.4098 - val_loss: 0.2932 - val_mae: 0.3662 - learning_rate: 5.0000e-04
# Epoch 100/100
# 786/800 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3810 - mae: 0.4091
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3787 - mae: 0.4091 - val_loss: 0.2931 - val_mae: 0.3661 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 95.
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1793/1793 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Optimal threshold (95th percentile): 0.7723
#
# ==================================================
# ANOMALY DETECTION RESULTS
# ==================================================
# Threshold: 0.7723
# Fraud detection rate: 85.77%
# False positive rate: 4.94%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.97     56863
#        Fraud       0.13      0.86      0.23       492
#
#     accuracy                           0.95     57355
#    macro avg       0.56      0.90      0.60     57355
# weighted avg       0.99      0.95      0.97     57355
# ROC AUC Score: 0.9502
#
# ==================================================
# EXAMPLE ANALYSIS
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Normal transactions reconstruction errors: [0.07742237 0.05570443 0.15497508]
# Fraud transactions reconstruction errors: [2.98847657 1.06295918 3.49196108]
# Threshold: 0.7723478723408324
#
# Top 10 features contributing to reconstruction error:
#    Feature  Reconstruction_Error
# 23     V24              0.643256
# 14     V15              0.597388
# 24     V25              0.589949
# 21     V22              0.541655
# 18     V19              0.483559
# 15     V16              0.470803
# 16     V17              0.449221
# 8       V9              0.433210
# 10     V11              0.422864
# 17     V18              0.414793

# %%
# a. Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# b. Upload / access the dataset
# Load the ECG dataset
df = pd.read_csv('ecg_autoencoder_dataset.csv', header=None)

# Explore the dataset
print("Dataset shape:", df.shape)
print("\nDataset info:")
print(df.info())
print("\nFirst few rows of data:")
print(df.head())

# The last column is the target (0: normal, 1: anomaly)
# First 140 columns are ECG signal features
features = df.iloc[:, :-1]  # All columns except last
labels = df.iloc[:, -1]     # Last column is the target

print(f"\nFeatures shape: {features.shape}")
print(f"Labels shape: {labels.shape}")

# Check class distribution
print("\nClass distribution:")
print(labels.value_counts())
print("\nPercentage of anomaly cases: {:.4f}%".format(labels.value_counts()[1] / len(labels) * 100))

# Split the data into normal and anomalous ECG signals
normal_data = features[labels == 0]
anomaly_data = features[labels == 1]

print(f"Normal ECG signals: {len(normal_data)}")
print(f"Anomalous ECG signals: {len(anomaly_data)}")

# Scale the features
scaler = StandardScaler()
normal_data_scaled = scaler.fit_transform(normal_data)
anomaly_data_scaled = scaler.transform(anomaly_data)

# Split normal data into train and test
X_train, X_test_normal = train_test_split(normal_data_scaled, test_size=0.2, random_state=42)

# Use all anomaly data for testing
X_test_anomaly = anomaly_data_scaled

# Combine test data
X_test = np.concatenate([X_test_normal, X_test_anomaly])
y_test = np.concatenate([np.zeros(len(X_test_normal)), np.ones(len(X_test_anomaly))])

print(f"\nTraining data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")

# Autoencoder architecture
input_dim = X_train.shape[1]  # Number of ECG features (140)
encoding_dim = 32  # Size of our encoded representations

print(f"\nInput dimension: {input_dim}")
print(f"Encoding dimension: {encoding_dim}")

# c. Encoder converts it into latent representation
# Input layer
input_layer = Input(shape=(input_dim,))

# Encoder
encoder = Dense(128, activation='relu')(input_layer)
encoder = Dropout(0.1)(encoder)
encoder = Dense(64, activation='relu')(encoder)
encoder = Dropout(0.1)(encoder)
encoder = Dense(encoding_dim, activation='relu')(encoder)

# Latent representation
latent_representation = Dense(encoding_dim // 2, activation='relu', name='bottleneck')(encoder)

# d. Decoder networks convert it back to the original input
# Decoder
decoder = Dense(encoding_dim, activation='relu')(latent_representation)
decoder = Dropout(0.1)(decoder)
decoder = Dense(64, activation='relu')(decoder)
decoder = Dropout(0.1)(decoder)
decoder = Dense(128, activation='relu')(decoder)
output_layer = Dense(input_dim, activation='linear')(decoder)

# Create autoencoder model
autoencoder = Model(inputs=input_layer, outputs=output_layer, name='autoencoder')

# Create encoder model
encoder_model = Model(inputs=input_layer, outputs=latent_representation, name='encoder')

# Compile the models
# e. Compile the models with Optimizer, Loss, and Evaluation Metrics
autoencoder.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',  # Mean Squared Error for reconstruction
    metrics=['mae']  # Mean Absolute Error as additional metric
)

print("\nAutoencoder architecture:")
autoencoder.summary()

# Train the autoencoder
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=8,
    min_lr=0.0001,
    verbose=1
)

print("\nTraining autoencoder on normal ECG signals only...")

# Train on normal ECG signals only
history = autoencoder.fit(
    X_train, X_train,
    epochs=100,
    batch_size=128,
    validation_split=0.1,
    callbacks=[early_stopping, reduce_lr],
    verbose=1,
    shuffle=True
)

# Evaluate the model
print("\nMaking predictions...")
train_predictions = autoencoder.predict(X_train, verbose=0)
test_predictions = autoencoder.predict(X_test, verbose=0)

# Calculate reconstruction error
train_mse = np.mean(np.power(X_train - train_predictions, 2), axis=1)
test_mse = np.mean(np.power(X_test - test_predictions, 2), axis=1)

# Plot training history
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Autoencoder Training Loss', fontweight='bold')
plt.ylabel('Loss (MSE)')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE', linewidth=2)
plt.plot(history.history['val_mae'], label='Validation MAE', linewidth=2)
plt.title('Autoencoder Training MAE', fontweight='bold')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Analyze reconstruction errors
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.hist(train_mse, bins=50, alpha=0.7, label='Normal (Train)', color='blue', density=True)
plt.xlabel('Reconstruction Error (MSE)')
plt.ylabel('Density')
plt.title('Reconstruction Error - Training Data (Normal ECG)', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
normal_test_mse = test_mse[y_test == 0]
anomaly_test_mse = test_mse[y_test == 1]

plt.hist(normal_test_mse, bins=50, alpha=0.7, label='Normal (Test)', color='green', density=True)
plt.hist(anomaly_test_mse, bins=50, alpha=0.7, label='Anomaly (Test)', color='red', density=True)
plt.xlabel('Reconstruction Error (MSE)')
plt.ylabel('Density')
plt.title('Reconstruction Error - Test Data', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Find optimal threshold using training data
threshold = np.percentile(train_mse, 95)  # 95th percentile of training errors
print(f"\nOptimal threshold (95th percentile): {threshold:.4f}")

# Make predictions based on threshold
y_pred = (test_mse > threshold).astype(int)

# Evaluation metrics
print("\n" + "="*60)
print("ECG ANOMALY DETECTION RESULTS")
print("="*60)

print(f"Threshold: {threshold:.4f}")
print(f"Anomaly detection rate (Recall): {np.mean(y_pred[y_test == 1]) * 100:.2f}%")
print(f"False positive rate: {np.mean(y_pred[y_test == 0]) * 100:.2f}%")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Normal ECG', 'Anomalous ECG']))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Anomaly'], 
            yticklabels=['Normal', 'Anomaly'])
plt.title('ECG Anomaly Detection - Confusion Matrix', fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, test_mse)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ECG Anomaly Detection - ROC Curve', fontweight='bold')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.show()

print(f"ROC AUC Score: {roc_auc:.4f}")

# Analyze some examples
print("\n" + "="*60)
print("EXAMPLE ANALYSIS")
print("="*60)

# Get some examples
normal_examples = X_test[y_test == 0][:3]
anomaly_examples = X_test[y_test == 1][:3]

normal_reconstructions = autoencoder.predict(normal_examples, verbose=0)
anomaly_reconstructions = autoencoder.predict(anomaly_examples, verbose=0)

normal_errors = np.mean(np.power(normal_examples - normal_reconstructions, 2), axis=1)
anomaly_errors = np.mean(np.power(anomaly_examples - anomaly_reconstructions, 2), axis=1)

print("Normal ECG reconstruction errors:", normal_errors)
print("Anomalous ECG reconstruction errors:", anomaly_errors)
print("Threshold:", threshold)

# Visualize some ECG signals and their reconstructions
plt.figure(figsize=(15, 10))

# Plot normal ECG reconstruction
plt.subplot(2, 3, 1)
plt.plot(normal_examples[0], 'b-', alpha=0.7, label='Original')
plt.plot(normal_reconstructions[0], 'r--', alpha=0.7, label='Reconstructed')
plt.title(f'Normal ECG\nReconstruction Error: {normal_errors[0]:.4f}', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 2)
plt.plot(normal_examples[1], 'b-', alpha=0.7, label='Original')
plt.plot(normal_reconstructions[1], 'r--', alpha=0.7, label='Reconstructed')
plt.title(f'Normal ECG\nReconstruction Error: {normal_errors[1]:.4f}', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 3)
plt.plot(normal_examples[2], 'b-', alpha=0.7, label='Original')
plt.plot(normal_reconstructions[2], 'r--', alpha=0.7, label='Reconstructed')
plt.title(f'Normal ECG\nReconstruction Error: {normal_errors[2]:.4f}', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot anomalous ECG reconstruction
plt.subplot(2, 3, 4)
plt.plot(anomaly_examples[0], 'g-', alpha=0.7, label='Original')
plt.plot(anomaly_reconstructions[0], 'r--', alpha=0.7, label='Reconstructed')
plt.title(f'Anomalous ECG\nReconstruction Error: {anomaly_errors[0]:.4f}', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 5)
plt.plot(anomaly_examples[1], 'g-', alpha=0.7, label='Original')
plt.plot(anomaly_reconstructions[1], 'r--', alpha=0.7, label='Reconstructed')
plt.title(f'Anomalous ECG\nReconstruction Error: {anomaly_errors[1]:.4f}', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 3, 6)
plt.plot(anomaly_examples[2], 'g-', alpha=0.7, label='Original')
plt.plot(anomaly_reconstructions[2], 'r--', alpha=0.7, label='Reconstructed')
plt.title(f'Anomalous ECG\nReconstruction Error: {anomaly_errors[2]:.4f}', fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.suptitle('ECG Signal Reconstruction - Original vs Autoencoder Output', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# Feature importance analysis (which time points contribute most to reconstruction error)
time_point_errors = np.mean(np.abs(X_test - test_predictions), axis=0)
time_points = range(1, len(time_point_errors) + 1)

plt.figure(figsize=(12, 6))
plt.plot(time_points, time_point_errors, 'b-', alpha=0.7)
plt.xlabel('Time Point')
plt.ylabel('Average Reconstruction Error')
plt.title('Reconstruction Error Across ECG Time Points', fontweight='bold')
plt.grid(True, alpha=0.3)

# Highlight top 10 time points with highest errors
top_10_indices = np.argsort(time_point_errors)[-10:]
for idx in top_10_indices:
    plt.axvline(x=idx+1, color='red', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

print("\nTop 10 time points with highest reconstruction errors:")
for i, idx in enumerate(top_10_indices[::-1]):
    print(f"{i+1}. Time Point {idx+1}: Error = {time_point_errors[idx]:.4f}")

# Final summary
print("\n" + "="*70)
print("ECG ANOMALY DETECTION SUMMARY")
print("="*70)
print(f"📊 Dataset: ECG signals with {input_dim} time points")
print(f"🎯 Anomaly Detection Rate: {np.mean(y_pred[y_test == 1]) * 100:.2f}%")
print(f"🚫 False Positive Rate: {np.mean(y_pred[y_test == 0]) * 100:.2f}%")
print(f"📈 ROC AUC Score: {roc_auc:.4f}")
print(f"🔧 Autoencoder Architecture: {input_dim} → 128 → 64 → {encoding_dim} → {encoding_dim//2} → ...")
print(f"⚙️ Optimizer: Adam (lr=0.001)")
print(f"📏 Threshold: {threshold:.4f} (95th percentile of normal data)")
print(f"💾 Training samples: {X_train.shape[0]:,}")
print(f"🧪 Test samples: {X_test.shape[0]:,}")
print("="*70)

# Save the model
autoencoder.save('ecg_anomaly_detector.h5')
print(f"\n✓ Model saved as 'ecg_anomaly_detector.h5'")
# Out:
# Dataset shape: (4998, 141)
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4998 entries, 0 to 4997
# Columns: 141 entries, 0 to 140
# dtypes: float64(140), int64(1)
# memory usage: 5.4 MB
# None
#
# First few rows of data:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
#
#         135       136       137       138       139  140
# 0  0.257740  0.228077  0.123431  0.925286  0.193137    1
# 1  0.555784  0.476333  0.773820  1.119621 -1.436250    1
# 2 -0.713683 -0.532197  0.321097  0.904227 -0.421797    1
# 3  0.952074  0.990133  1.086798  1.403011 -0.383564    1
# 4  1.277392  0.960304  0.971020  1.614392  1.421456    1
#
# [5 rows x 141 columns]
#
# Features shape: (4998, 140)
# Labels shape: (4998,)
#
# Class distribution:
# 140
# 1    2919
# 0    2079
# Name: count, dtype: int64
#
# Percentage of anomaly cases: 58.4034%
# Normal ECG signals: 2079
# Anomalous ECG signals: 2919
#
# Training data shape: (1663, 140)
# Test data shape: (3335, 140)
#
# Input dimension: 140
# Encoding dimension: 32
#
# Autoencoder architecture:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 140)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          18,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bottleneck (Dense)                   │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 140)                 │          18,060 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,948 (226.36 KB)
#  Trainable params: 57,948 (226.36 KB)
#  Non-trainable params: 0 (0.00 B)
# Training autoencoder on normal ECG signals only...
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.9683 - mae: 0.6891 - val_loss: 0.7727 - val_mae: 0.6350 - learning_rate: 0.0010
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8318 - mae: 0.6361 - val_loss: 0.6802 - val_mae: 0.5947 - learning_rate: 0.0010
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7757 - mae: 0.6105 - val_loss: 0.6512 - val_mae: 0.5744 - learning_rate: 0.0010
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7272 - mae: 0.5847 - val_loss: 0.6081 - val_mae: 0.5467 - learning_rate: 0.0010
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6663 - mae: 0.5572 - val_loss: 0.5528 - val_mae: 0.5191 - learning_rate: 0.0010
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5820 - mae: 0.5191 - val_loss: 0.4776 - val_mae: 0.4716 - learning_rate: 0.0010
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5228 - mae: 0.4799 - val_loss: 0.4420 - val_mae: 0.4431 - learning_rate: 0.0010
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4914 - mae: 0.4585 - val_loss: 0.4070 - val_mae: 0.4147 - learning_rate: 0.0010
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4718 - mae: 0.4408 - val_loss: 0.3713 - val_mae: 0.3859 - learning_rate: 0.0010
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4490 - mae: 0.4260 - val_loss: 0.3593 - val_mae: 0.3789 - learning_rate: 0.0010
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4358 - mae: 0.4178 - val_loss: 0.3464 - val_mae: 0.3696 - learning_rate: 0.0010
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4277 - mae: 0.4114 - val_loss: 0.3482 - val_mae: 0.3710 - learning_rate: 0.0010
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4141 - mae: 0.4068 - val_loss: 0.3301 - val_mae: 0.3591 - learning_rate: 0.0010
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4015 - mae: 0.3978 - val_loss: 0.3151 - val_mae: 0.3488 - learning_rate: 0.0010
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3922 - mae: 0.3945 - val_loss: 0.3044 - val_mae: 0.3432 - learning_rate: 0.0010
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3801 - mae: 0.3874 - val_loss: 0.3079 - val_mae: 0.3458 - learning_rate: 0.0010
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3806 - mae: 0.3848 - val_loss: 0.2996 - val_mae: 0.3420 - learning_rate: 0.0010
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3689 - mae: 0.3809 - val_loss: 0.2865 - val_mae: 0.3319 - learning_rate: 0.0010
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3526 - mae: 0.3736 - val_loss: 0.2844 - val_mae: 0.3268 - learning_rate: 0.0010
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3539 - mae: 0.3720 - val_loss: 0.2798 - val_mae: 0.3218 - learning_rate: 0.0010
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3421 - mae: 0.3669 - val_loss: 0.2767 - val_mae: 0.3214 - learning_rate: 0.0010
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3417 - mae: 0.3673 - val_loss: 0.2661 - val_mae: 0.3133 - learning_rate: 0.0010
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3246 - mae: 0.3623 - val_loss: 0.2636 - val_mae: 0.3101 - learning_rate: 0.0010
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3180 - mae: 0.3589 - val_loss: 0.2641 - val_mae: 0.3123 - learning_rate: 0.0010
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3131 - mae: 0.3541 - val_loss: 0.2563 - val_mae: 0.3084 - learning_rate: 0.0010
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3114 - mae: 0.3544 - val_loss: 0.2540 - val_mae: 0.3077 - learning_rate: 0.0010
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3030 - mae: 0.3488 - val_loss: 0.2500 - val_mae: 0.3022 - learning_rate: 0.0010
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3003 - mae: 0.3477 - val_loss: 0.2450 - val_mae: 0.2994 - learning_rate: 0.0010
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2945 - mae: 0.3470 - val_loss: 0.2466 - val_mae: 0.2996 - learning_rate: 0.0010
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2863 - mae: 0.3415 - val_loss: 0.2390 - val_mae: 0.2923 - learning_rate: 0.0010
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2866 - mae: 0.3409 - val_loss: 0.2373 - val_mae: 0.2914 - learning_rate: 0.0010
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2855 - mae: 0.3418 - val_loss: 0.2437 - val_mae: 0.2977 - learning_rate: 0.0010
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2811 - mae: 0.3372 - val_loss: 0.2460 - val_mae: 0.2990 - learning_rate: 0.0010
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2768 - mae: 0.3367 - val_loss: 0.2405 - val_mae: 0.2918 - learning_rate: 0.0010
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2819 - mae: 0.3367 - val_loss: 0.2335 - val_mae: 0.2876 - learning_rate: 0.0010
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2731 - mae: 0.3351 - val_loss: 0.2357 - val_mae: 0.2932 - learning_rate: 0.0010
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2772 - mae: 0.3344 - val_loss: 0.2330 - val_mae: 0.2890 - learning_rate: 0.0010
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2685 - mae: 0.3300 - val_loss: 0.2350 - val_mae: 0.2883 - learning_rate: 0.0010
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2647 - mae: 0.3267 - val_loss: 0.2321 - val_mae: 0.2873 - learning_rate: 0.0010
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2571 - mae: 0.3265 - val_loss: 0.2413 - val_mae: 0.2956 - learning_rate: 0.0010
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2620 - mae: 0.3274 - val_loss: 0.2305 - val_mae: 0.2862 - learning_rate: 0.0010
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2537 - mae: 0.3256 - val_loss: 0.2319 - val_mae: 0.2846 - learning_rate: 0.0010
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2543 - mae: 0.3232 - val_loss: 0.2267 - val_mae: 0.2843 - learning_rate: 0.0010
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2478 - mae: 0.3235 - val_loss: 0.2272 - val_mae: 0.2840 - learning_rate: 0.0010
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2532 - mae: 0.3223 - val_loss: 0.2252 - val_mae: 0.2802 - learning_rate: 0.0010
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2494 - mae: 0.3225 - val_loss: 0.2312 - val_mae: 0.2883 - learning_rate: 0.0010
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2513 - mae: 0.3218 - val_loss: 0.2228 - val_mae: 0.2813 - learning_rate: 0.0010
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2471 - mae: 0.3202 - val_loss: 0.2224 - val_mae: 0.2786 - learning_rate: 0.0010
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2412 - mae: 0.3169 - val_loss: 0.2249 - val_mae: 0.2833 - learning_rate: 0.0010
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2408 - mae: 0.3156 - val_loss: 0.2225 - val_mae: 0.2783 - learning_rate: 0.0010
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2467 - mae: 0.3167 - val_loss: 0.2255 - val_mae: 0.2822 - learning_rate: 0.0010
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2495 - mae: 0.3206 - val_loss: 0.2234 - val_mae: 0.2816 - learning_rate: 0.0010
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2335 - mae: 0.3144 - val_loss: 0.2230 - val_mae: 0.2785 - learning_rate: 0.0010
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2330 - mae: 0.3147 - val_loss: 0.2202 - val_mae: 0.2751 - learning_rate: 0.0010
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2387 - mae: 0.3121 - val_loss: 0.2164 - val_mae: 0.2731 - learning_rate: 0.0010
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2273 - mae: 0.3095 - val_loss: 0.2172 - val_mae: 0.2762 - learning_rate: 0.0010
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2337 - mae: 0.3134 - val_loss: 0.2210 - val_mae: 0.2770 - learning_rate: 0.0010
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2289 - mae: 0.3082 - val_loss: 0.2154 - val_mae: 0.2730 - learning_rate: 0.0010
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2188 - mae: 0.3042 - val_loss: 0.2188 - val_mae: 0.2734 - learning_rate: 0.0010
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2244 - mae: 0.3068 - val_loss: 0.2098 - val_mae: 0.2674 - learning_rate: 0.0010
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2220 - mae: 0.3083 - val_loss: 0.2136 - val_mae: 0.2701 - learning_rate: 0.0010
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2232 - mae: 0.3078 - val_loss: 0.2148 - val_mae: 0.2716 - learning_rate: 0.0010
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2208 - mae: 0.3049 - val_loss: 0.2144 - val_mae: 0.2731 - learning_rate: 0.0010
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2222 - mae: 0.3045 - val_loss: 0.2166 - val_mae: 0.2735 - learning_rate: 0.0010
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2111 - mae: 0.3004 - val_loss: 0.2088 - val_mae: 0.2657 - learning_rate: 0.0010
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2184 - mae: 0.3036 - val_loss: 0.2131 - val_mae: 0.2672 - learning_rate: 0.0010
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2142 - mae: 0.3026 - val_loss: 0.2084 - val_mae: 0.2634 - learning_rate: 0.0010
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2112 - mae: 0.2993 - val_loss: 0.2114 - val_mae: 0.2669 - learning_rate: 0.0010
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2164 - mae: 0.3015 - val_loss: 0.2168 - val_mae: 0.2761 - learning_rate: 0.0010
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2130 - mae: 0.3003 - val_loss: 0.2204 - val_mae: 0.2747 - learning_rate: 0.0010
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2106 - mae: 0.3013 - val_loss: 0.2136 - val_mae: 0.2677 - learning_rate: 0.0010
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2134 - mae: 0.3001 - val_loss: 0.2100 - val_mae: 0.2623 - learning_rate: 0.0010
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2069 - mae: 0.2958 - val_loss: 0.2080 - val_mae: 0.2631 - learning_rate: 0.0010
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2053 - mae: 0.2963 - val_loss: 0.2085 - val_mae: 0.2668 - learning_rate: 0.0010
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2087 - mae: 0.2968 - val_loss: 0.2103 - val_mae: 0.2663 - learning_rate: 0.0010
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2071 - mae: 0.2958 - val_loss: 0.2123 - val_mae: 0.2681 - learning_rate: 0.0010
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2088 - mae: 0.2968 - val_loss: 0.2129 - val_mae: 0.2695 - learning_rate: 0.0010
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2033 - mae: 0.2942 - val_loss: 0.2036 - val_mae: 0.2599 - learning_rate: 0.0010
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2050 - mae: 0.2953 - val_loss: 0.2057 - val_mae: 0.2601 - learning_rate: 0.0010
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2022 - mae: 0.2933 - val_loss: 0.2053 - val_mae: 0.2602 - learning_rate: 0.0010
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2039 - mae: 0.2931 - val_loss: 0.2071 - val_mae: 0.2610 - learning_rate: 0.0010
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2001 - mae: 0.2918 - val_loss: 0.2091 - val_mae: 0.2632 - learning_rate: 0.0010
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1965 - mae: 0.2910 - val_loss: 0.2083 - val_mae: 0.2607 - learning_rate: 0.0010
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1964 - mae: 0.2908 - val_loss: 0.2079 - val_mae: 0.2616 - learning_rate: 0.0010
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2000 - mae: 0.2921 - val_loss: 0.2068 - val_mae: 0.2613 - learning_rate: 0.0010
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2129 - mae: 0.2958
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1999 - mae: 0.2915 - val_loss: 0.2072 - val_mae: 0.2639 - learning_rate: 0.0010
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1915 - mae: 0.2867 - val_loss: 0.2003 - val_mae: 0.2565 - learning_rate: 5.0000e-04
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1959 - mae: 0.2887 - val_loss: 0.2063 - val_mae: 0.2619 - learning_rate: 5.0000e-04
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1913 - mae: 0.2887 - val_loss: 0.1981 - val_mae: 0.2535 - learning_rate: 5.0000e-04
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1874 - mae: 0.2840 - val_loss: 0.2040 - val_mae: 0.2588 - learning_rate: 5.0000e-04
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1863 - mae: 0.2861 - val_loss: 0.1991 - val_mae: 0.2543 - learning_rate: 5.0000e-04
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1895 - mae: 0.2863 - val_loss: 0.2001 - val_mae: 0.2562 - learning_rate: 5.0000e-04
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1913 - mae: 0.2873 - val_loss: 0.2027 - val_mae: 0.2595 - learning_rate: 5.0000e-04
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1915 - mae: 0.2856 - val_loss: 0.1998 - val_mae: 0.2552 - learning_rate: 5.0000e-04
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1879 - mae: 0.2855 - val_loss: 0.2054 - val_mae: 0.2612 - learning_rate: 5.0000e-04
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1896 - mae: 0.2852 - val_loss: 0.1963 - val_mae: 0.2521 - learning_rate: 5.0000e-04
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1919 - mae: 0.2855 - val_loss: 0.1968 - val_mae: 0.2543 - learning_rate: 5.0000e-04
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1902 - mae: 0.2844 - val_loss: 0.1971 - val_mae: 0.2530 - learning_rate: 5.0000e-04
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1822 - mae: 0.2824 - val_loss: 0.2002 - val_mae: 0.2570 - learning_rate: 5.0000e-04
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1875 - mae: 0.2846 - val_loss: 0.1988 - val_mae: 0.2549 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 96.
#
# Making predictions...
# Optimal threshold (95th percentile): 0.4489
#
# ============================================================
# ECG ANOMALY DETECTION RESULTS
# ============================================================
# Threshold: 0.4489
# Anomaly detection rate (Recall): 83.86%
# False positive rate: 6.01%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    Normal ECG       0.45      0.94      0.61       416
# Anomalous ECG       0.99      0.84      0.91      2919
#
#      accuracy                           0.85      3335
#     macro avg       0.72      0.89      0.76      3335
#  weighted avg       0.92      0.85      0.87      3335
# ROC AUC Score: 0.9577
#
# ============================================================
# EXAMPLE ANALYSIS
# ============================================================
# Normal ECG reconstruction errors: [0.04164275 0.5067238  0.11926289]
# Anomalous ECG reconstruction errors: [1.07386357 1.17111662 0.67535764]
# Threshold: 0.44885664552663623
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Top 10 time points with highest reconstruction errors:
# 1. Time Point 95: Error = 1.5614
# 2. Time Point 97: Error = 1.5228
# 3. Time Point 96: Error = 1.5163
# 4. Time Point 98: Error = 1.5140
# 5. Time Point 94: Error = 1.4498
# 6. Time Point 108: Error = 1.4030
# 7. Time Point 99: Error = 1.3821
# 8. Time Point 107: Error = 1.3721
# 9. Time Point 100: Error = 1.2536
# 10. Time Point 106: Error = 1.2429
#
# ======================================================================
# ECG ANOMALY DETECTION SUMMARY
# ======================================================================
# 📊 Dataset: ECG signals with 140 time points
# 🎯 Anomaly Detection Rate: 83.86%
# 🚫 False Positive Rate: 6.01%
# 📈 ROC AUC Score: 0.9577
# 🔧 Autoencoder Architecture: 140 → 128 → 64 → 32 → 16 → ...
# ⚙️ Optimizer: Adam (lr=0.001)
# 📏 Threshold: 0.4489 (95th percentile of normal data)
# 💾 Training samples: 1,663
# 🧪 Test samples: 3,335
# ======================================================================
#
# ✓ Model saved as 'ecg_anomaly_detector.h5'
